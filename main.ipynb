# %%
import glob
import cv2 
import os 
import numpy as np 
import matplotlib.pyplot as plt

# %%
body_front = 'C:\\Users\\Vimal\\Desktop\\ibm\\Car damage\\body\\training\\00-front'
body_rear = "C:\\Users\\Vimal\\Desktop\\ibm\\Car damage\\body\\training\\01-rear"
body_side = 'C:\\Users\\Vimal\\Desktop\\ibm\\Car damage\\body\\training\\02-side'

level_minor = 'C:\\Users\\Vimal\\Desktop\\ibm\\Car damage\\level\\training\\01-minor'
level_mod = 'C:\\Users\\Vimal\\Desktop\\ibm\\Car damage\\level\\training\\02-moderate'
level_ser = "C:\\Users\\Vimal\\Desktop\\ibm\\Car damage\\level\\training\\03-severe"

# %%
os.chdir(body_front)
dir = os.getcwd()
body_fr = []
body_fr_label = []
for i in range(len(os.listdir(dir))):
    img = cv2.imread(os.listdir(dir)[i])
    temp = cv2.resize(img,(150,150)) 
    body_fr.append(temp)
    body_fr_label.append('Front Body')

# %%
os.chdir(body_rear)
dir = os.getcwd()
body_re = [] 
body_re_label = []
for i in range(len(os.listdir(dir))):
    img = cv2.imread(os.listdir(dir)[i])
    temp = cv2.resize(img,(150,150))
    body_re.append(temp)
    body_re_label.append('Rear Body')

# %%
os.chdir(body_side )
dir = os.getcwd()
body_si = [] 
body_si_label = []
for i in range(len(os.listdir(dir))):
    img = cv2.imread(os.listdir(dir)[i])
    temp = cv2.resize(img,(150,150))
    body_si.append(temp)
    body_si_label.append('Side Body')

# %%
body_fr = np.asarray(body_fr)
body_re = np.asarray(body_re)
# Out:
# (419, 150, 150, 3)

# %%
plt.imshow(body_fr[1])
